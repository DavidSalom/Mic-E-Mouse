# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv
from core.preprocess import *

# %%
filename = 'data/data_2023-10-19_20-58-11.csv'

a,b,c = processFromFile(filename)

# print("df4")

# dataframe = pd.read_csv(filename, sep=r'\s*,\s*', header=0, encoding='ascii', engine='python')

# print("df2")

# df = pd.DataFrame(dataframe) 
  
# X = list(df.iloc[:, 0]) 
# Y = list(df.iloc[:, 1]) 
  
# # Plot the data using bar() method 
# plt.bar(X, Y, color='g') 
# plt.title("Students over 11 Years") 
# plt.xlabel("Years") 
# plt.ylabel("Number of Students") 

# print("df")

# # Show the plot 
# plt.show() 




# dataframe = pd.read_csv(filename, sep=r'\s*,\s*',
#                            header=0, encoding='ascii', engine='python')



# #dataframe["offset"] = pd.to_datetime(dataframe['offset'], format="%Y-%m-%d")

# fig, ax = plt.subplots()
# ax.plot(dataframe["offset"], dataframe["x"])
# ax.plot(dataframe["offset"], dataframe["y"])
# #fig.autofmt_xdate()
# fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: could not convert string to float: 'offset'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 filename = 'data/data_2023-10-19_20-58-11.csv'
# ----> 3 a,b,c = processFromFile(filename)
#       5 # print("df4")
#       6
#       7 # dataframe = pd.read_csv(filename, sep=r'\s*,\s*', header=0, encoding='ascii', engine='python')
#    (...)
#      40 # #fig.autofmt_xdate()
#      41 # fig.show()
#
# File ~/saki/research/Mic-E-Mouse/core/preprocess.py:148, in processFromFile(fn)
#     144 def processFromFile(fn):
#     145     """
#     146     Convenience function to load, resample, and project data from a file. This is the typical use case of the preprocessing pipeline.
#     147     """
# --> 148     nuT, nuX, nuY = loadData(fn)
#     149     T, X, Y = resample(nuT, nuX, nuY)
#     150     projX, projY = project(X, Y)
#
# File ~/saki/research/Mic-E-Mouse/core/preprocess.py:15, in loadData(src)
#       9 """
#      10 Load the data from the source file and return it as a PyTorch tensor.
#      11 :param src: The path to the source file.
#      12 :return: A Tuple containing the time vector, the nonuniform X vector, and the nonuniform Y vector.
#      13 """
#      14 # Load the data from the source file
# ---> 15 data = np.loadtxt(src, delimiter=',')
#      16 # Convert the data into a PyTorch tensor
#      17 data = torch.from_numpy(data)
#
# File /usr/lib/python3.11/site-packages/numpy/lib/npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
#    1378 return arr
#
# File /usr/lib/python3.11/site-packages/numpy/lib/npyio.py:1016, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#    1013     data = _preprocess_comments(data, comments, encoding)
#    1015 if read_dtype_via_object_chunks is None:
# -> 1016     arr = _load_from_filelike(
#    1017         data, delimiter=delimiter, comment=comment, quote=quote,
#    1018         imaginary_unit=imaginary_unit,
#    1019         usecols=usecols, skiplines=skiplines, max_rows=max_rows,
#    1020         converters=converters, dtype=dtype,
#    1021         encoding=encoding, filelike=filelike,
#    1022         byte_converters=byte_converters)
#    1024 else:
#    1025     # This branch reads the file into chunks of object arrays and then
#    1026     # casts them to the desired actual dtype.  This ensures correct
#    1027     # string-length and datetime-unit discovery (like `arr.astype()`).
#    1028     # Due to chunking, certain error reports are less clear, currently.
#    1029     if filelike:
#
# ValueError: could not convert string 'offset' to float64 at row 0, column 1.
