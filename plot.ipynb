# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv
from core.preprocess import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
filename = 'vctk/gen/csv/wav48_silence_trimmed/p243/p243_196_mic2.csv'
a,b,c = processFromFile(filename)

# print("df4")

# dataframe = pd.read_csv(filename, sep=r'\s*,\s*', header=0, encoding='ascii', engine='python')

# print("df2")

# df = pd.DataFrame(dataframe) 
  
# X = list(df.iloc[:, 0]) 
# Y = list(df.iloc[:, 1]) 
  
# # Plot the data using bar() method 
# plt.bar(X, Y, color='g') 
# plt.title("Students over 11 Years") 
# plt.xlabel("Years") 
# plt.ylabel("Number of Students") 

# print("df")

# # Show the plot 
# plt.show() 




# dataframe = pd.read_csv(filename, sep=r'\s*,\s*',
#                            header=0, encoding='ascii', engine='python')



# #dataframe["offset"] = pd.to_datetime(dataframe['offset'], format="%Y-%m-%d")

# fig, ax = plt.subplots()
# ax.plot(dataframe["offset"], dataframe["x"])
# ax.plot(dataframe["offset"], dataframe["y"])
# #fig.autofmt_xdate()
# fig.show()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 77913/77913 [00:10<00:00, 7130.86it/s]

# %%
len(b)/16000
# Out:
# 4.869625

# %%
import torch

# %%
st = torch.stft(b, n_fft=512, hop_length=256, win_length=256, center=False, pad_mode='reflect', normalized=False, onesided=True, return_complex=False)[:, :, 0]

# %%
plt.imshow(torch.abs(st), origin='lower', aspect='auto')
